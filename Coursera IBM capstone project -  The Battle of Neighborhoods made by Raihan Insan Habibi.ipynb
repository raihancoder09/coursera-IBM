# %% [markdown]
# # Coursera IBM capstone project -  The Battle of Neighborhoods

# %% [markdown]
# <p> project title: </p>

# %% [markdown]
# <h2>Analytical strategy to control the location that has populated Diabetes in Riyadh, Saudi Arabia using Data Science</h2>

# %% [markdown]
# <p> Author: Raihan Insan Habibi</p>

# %% [markdown]
# <b>1. Introduction / business problems</b>

# %% [markdown]
# In Saudi Arabia, Diabetes is one of the top 10 causes of death. By the beginning of 2020, approximately 20% of adulteries of the whole population (estimated around 34 million people) has Type 1 Diabetes. and almost 70% of the people are overweight, and 30% are obese, these factors of bad habit can lead to Type 2 diabetes. While many scientists are still finding new ways to prevent this, other experts like Data scientists need access to data and information for current situations in the city, such as the availability and the geographic distribution. Where is the most populated place that has diabetes? What is the cause of it? Is the city more dense with restaurants than other places like museums, parks, gyms, etc? In this report, I will talk about how these questions can lead to better results by describing simple analysis by using data science and visual tool kits.
